# %% [markdown]
# # RAG using Upstage Document Parse and Groundedness Check
# 使用 Upstage 文档解析和接地性检查的 RAG
#
# Upstage 是一家领先的人工智能 (AI) 公司，专门提供高于人类水平性能的 LLM 组件。langchain集成了upstage模块
#
# This example illustrates RAG using [Upstage](https://python.langchain.com/docs/integrations/providers/upstage/) Document Parse and Groundedness Check.

# %%
from typing import List

from dotenv import load_dotenv
load_dotenv()

from langchain_community.vectorstores import DocArrayInMemorySearch
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.runnables.base import RunnableSerializable
from langchain_upstage import (
    ChatUpstage,
    UpstageDocumentParseLoader,
    UpstageEmbeddings,
    UpstageGroundednessCheck,
)

model = ChatUpstage()

files = ["D:/Code/langchain_sample/langchain_cookbook/docs/15天AI Agent工程师面试学习路线-2f931c0bb2.pdf", 
         "D:/Code/langchain_sample/langchain_cookbook/docs/美团10.1红包活动分镜脚本及制作指导-83a64b0abb.pdf"]

loader = UpstageDocumentParseLoader(file_path=files, split="element")

docs = loader.load()

# %%
print(f"docs type {type(docs)}")
# Out:
# docs type <class 'list'>

# %%
for doc in docs:
    print(doc)
# Out:
# page_content='<p id='0' data-category='list'></p>' metadata={'id': 0, 'page': 1, 'category': 'list', 'coordinates': [{'x': 0.1155, 'y': 0.4467}, {'x': 0.526, 'y': 0.4467}, {'x': 0.526, 'y': 0.515}, {'x': 0.1155, 'y': 0.515}]}
# page_content='<p id='1' data-category='list'></p>' metadata={'id': 1, 'page': 1, 'category': 'list', 'coordinates': [{'x': 0.1158, 'y': 0.5557}, {'x': 0.4494, 'y': 0.5557}, {'x': 0.4494, 'y': 0.5985}, {'x': 0.1158, 'y': 0.5985}]}
# page_content='<p id='2' data-category='list'></p>' metadata={'id': 2, 'page': 1, 'category': 'list', 'coordinates': [{'x': 0.1132, 'y': 0.7154}, {'x': 0.7287, 'y': 0.7154}, {'x': 0.7287, 'y': 0.784}, {'x': 0.1132, 'y': 0.784}]}
# page_content='<p id='3' data-category='list'></p>' metadata={'id': 3, 'page': 1, 'category': 'list', 'coordinates': [{'x': 0.115, 'y': 0.8243}, {'x': 0.6305, 'y': 0.8243}, {'x': 0.6305, 'y': 0.8693}, {'x': 0.115, 'y': 0.8693}]}
# page_content='<p id='4' data-category='paragraph' style='font-size:14px'>asyncio</p>' metadata={'id': 4, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.2316, 'y': 3.0329}, {'x': 0.2978, 'y': 3.0329}, {'x': 0.2978, 'y': 3.0456}, {'x': 0.2316, 'y': 3.0456}]}
# page_content='<p id='5' data-category='paragraph' style='font-size:16px'>API</p>' metadata={'id': 5, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.2483, 'y': 3.3602}, {'x': 0.282, 'y': 3.3602}, {'x': 0.282, 'y': 3.3752}, {'x': 0.2483, 'y': 3.3752}]}
# page_content='<br><p id='6' data-category='paragraph' style='font-size:16px'>编程、</p>' metadata={'id': 6, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.2358, 'y': 3.3578}, {'x': 0.2923, 'y': 3.3578}, {'x': 0.2923, 'y': 3.3727}, {'x': 0.2358, 'y': 3.3727}]}
# page_content='<br><p id='7' data-category='paragraph' style='font-size:16px'>基础巩固（3天）、核心技术（7天）、项目实战（3天）、面试冲刺（2天）</p>' metadata={'id': 7, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1633, 'y': 3.1823}, {'x': 0.7515, 'y': 3.1823}, {'x': 0.7515, 'y': 3.1973}, {'x': 0.1633, 'y': 3.1973}]}
# page_content='<p id='8' data-category='paragraph' style='font-size:16px'>核心编程（必备技能）</p>' metadata={'id': 8, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.2189, 'y': 3.3729}, {'x': 0.4022, 'y': 3.3729}, {'x': 0.4022, 'y': 3.3878}, {'x': 0.2189, 'y': 3.3878}]}
# page_content='<p id='9' data-category='paragraph' style='font-size:16px'>：开发一个简单的天气查询API（接收城市参数，返回模拟天气数据）</p>' metadata={'id': 9, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.6274}, {'x': 0.7238, 'y': 3.6274}, {'x': 0.7238, 'y': 3.6424}, {'x': 0.1834, 'y': 3.6424}]}
# page_content='<br><p id='10' data-category='paragraph' style='font-size:16px'>工程师岗位核心要求（</p>' metadata={'id': 10, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1947, 'y': 3.1857}, {'x': 0.3746, 'y': 3.1857}, {'x': 0.3746, 'y': 3.2006}, {'x': 0.1947, 'y': 3.2006}]}
# page_content='<p id='11' data-category='paragraph' style='font-size:16px'>基础与 调用</p>' metadata={'id': 11, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1943, 'y': 3.6425}, {'x': 0.318, 'y': 3.6425}, {'x': 0.318, 'y': 3.6575}, {'x': 0.1943, 'y': 3.6575}]}
# page_content='<p id='12' data-category='paragraph' style='font-size:16px'>：调用GPT-4 API实现一个简单的智能问答机器人（支持上下文记忆）</p>' metadata={'id': 12, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.8966}, {'x': 0.7243, 'y': 3.8966}, {'x': 0.7243, 'y': 3.9116}, {'x': 0.1834, 'y': 3.9116}]}
# page_content='<br><p id='13' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 13, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.4344}, {'x': 0.2046, 'y': 3.4344}, {'x': 0.2046, 'y': 3.4493}, {'x': 0.1834, 'y': 3.4493}]}
# page_content='<p id='14' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 14, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.5435}, {'x': 0.2046, 'y': 3.5435}, {'x': 0.2046, 'y': 3.5585}, {'x': 0.1834, 'y': 3.5585}]}
# page_content='<p id='15' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 15, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.704}, {'x': 0.2046, 'y': 3.704}, {'x': 0.2046, 'y': 3.719}, {'x': 0.1834, 'y': 3.719}]}
# page_content='<br><p id='16' data-category='paragraph' style='font-size:16px'>◦ Python基础语法（变量、数据类型、函数/类设计）</p>' metadata={'id': 16, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.4577}, {'x': 0.5319, 'y': 3.4577}, {'x': 0.5319, 'y': 3.4744}, {'x': 0.1168, 'y': 3.4744}]}
# page_content='<p id='17' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 17, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.8128}, {'x': 0.2046, 'y': 3.8128}, {'x': 0.2046, 'y': 3.8278}, {'x': 0.1834, 'y': 3.8278}]}
# page_content='<br><p id='18' data-category='paragraph' style='font-size:16px'>◦ FastAPI官方文档（FastAPI Tutorial）</p>' metadata={'id': 18, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.5918}, {'x': 0.4161, 'y': 3.5918}, {'x': 0.4161, 'y': 3.6085}, {'x': 0.1168, 'y': 3.6085}]}
# page_content='<br><p id='19' data-category='paragraph' style='font-size:16px'>Python</p>' metadata={'id': 19, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1809, 'y': 3.0504}, {'x': 0.2394, 'y': 3.0504}, {'x': 0.2394, 'y': 3.0654}, {'x': 0.1809, 'y': 3.0654}]}
# page_content='<p id='20' data-category='paragraph' style='font-size:16px'>◦ Web框架入门（FastAPI快速搭建API服务）</p>' metadata={'id': 20, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.5079}, {'x': 0.464, 'y': 3.5079}, {'x': 0.464, 'y': 3.5247}, {'x': 0.1168, 'y': 3.5247}]}
# page_content='<p id='21' data-category='paragraph' style='font-size:16px'>◦ 《Python编程：从入门到实践》第1-5章</p>' metadata={'id': 21, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.5668}, {'x': 0.4474, 'y': 3.5668}, {'x': 0.4474, 'y': 3.5836}, {'x': 0.1168, 'y': 3.5836}]}
# page_content='<br><p id='22' data-category='paragraph' style='font-size:16px'>◦ 异步编程（</p>' metadata={'id': 22, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.4826}, {'x': 0.225, 'y': 3.4826}, {'x': 0.225, 'y': 3.4994}, {'x': 0.1168, 'y': 3.4994}]}
# page_content='<p id='23' data-category='paragraph' style='font-size:16px'>◦ LLM API调用（OpenAI GPT/Claude API使用，含API Key配置、请求参数调优）</p>' metadata={'id': 23, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.7522}, {'x': 0.7335, 'y': 3.7522}, {'x': 0.7335, 'y': 3.769}, {'x': 0.1168, 'y': 3.769}]}
# page_content='<br><p id='24' data-category='paragraph' style='font-size:16px'>◦ 基础Prompt设计（零样本/少样本提示、角色设定）</p>' metadata={'id': 24, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.7772}, {'x': 0.5344, 'y': 3.7772}, {'x': 0.5344, 'y': 3.794}, {'x': 0.1168, 'y': 3.794}]}
# page_content='<br><p id='25' data-category='paragraph' style='font-size:16px'>Python</p>' metadata={'id': 25, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1569, 'y': 3.0906}, {'x': 0.2221, 'y': 3.0906}, {'x': 0.2221, 'y': 3.1055}, {'x': 0.1569, 'y': 3.1055}]}
# page_content='<p id='26' data-category='paragraph' style='font-size:16px'>◦ OpenAI API官方文档（Function Calling指南）</p>' metadata={'id': 26, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.8361}, {'x': 0.4853, 'y': 3.8361}, {'x': 0.4853, 'y': 3.8529}, {'x': 0.1168, 'y': 3.8529}]}
# page_content='<br><p id='27' data-category='paragraph' style='font-size:16px'>◦ Transformer模型原理（Self-Attention机制）</p>' metadata={'id': 27, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.7273}, {'x': 0.4782, 'y': 3.7273}, {'x': 0.4782, 'y': 3.7441}, {'x': 0.1168, 'y': 3.7441}]}
# page_content='<p id='28' data-category='paragraph' style='font-size:16px'>◦ DeepLearning.AI《ChatGPT Prompt Engineering》课程（前3节）</p>' metadata={'id': 28, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.861}, {'x': 0.6336, 'y': 3.861}, {'x': 0.6336, 'y': 3.8778}, {'x': 0.1168, 'y': 3.8778}]}
# page_content='<br><p id='29' data-category='paragraph' style='font-size:16px'>1</p>' metadata={'id': 29, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1115, 'y': 3.0911}, {'x': 0.1233, 'y': 3.0911}, {'x': 0.1233, 'y': 3.105}, {'x': 0.1115, 'y': 3.105}]}
# page_content='<p id='30' data-category='paragraph' style='font-size:16px'>2 ：掌握 LLM</p>' metadata={'id': 30, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1104, 'y': 3.3575}, {'x': 0.1978, 'y': 3.3575}, {'x': 0.1978, 'y': 3.3754}, {'x': 0.1104, 'y': 3.3754}]}
# page_content='<p id='31' data-category='paragraph' style='font-size:16px'>学习资源</p>' metadata={'id': 31, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.5185}, {'x': 0.187, 'y': 3.5185}, {'x': 0.187, 'y': 3.5335}, {'x': 0.1129, 'y': 3.5335}]}
# page_content='<br><p id='32' data-category='paragraph' style='font-size:16px'>核心内容</p>' metadata={'id': 32, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.4094}, {'x': 0.187, 'y': 3.4094}, {'x': 0.187, 'y': 3.4243}, {'x': 0.1129, 'y': 3.4243}]}
# page_content='<p id='33' data-category='paragraph' style='font-size:16px'>学习资源</p>' metadata={'id': 33, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.7878}, {'x': 0.187, 'y': 3.7878}, {'x': 0.187, 'y': 3.8027}, {'x': 0.1129, 'y': 3.8027}]}
# page_content='<p id='34' data-category='paragraph' style='font-size:22px'>天</p>' metadata={'id': 34, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1233, 'y': 4.7699}, {'x': 0.1565, 'y': 4.7699}, {'x': 0.1565, 'y': 4.7934}, {'x': 0.1233, 'y': 4.7934}]}
# page_content='<br><p id='35' data-category='paragraph' style='font-size:16px'>核心内容</p>' metadata={'id': 35, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.679}, {'x': 0.187, 'y': 3.679}, {'x': 0.187, 'y': 3.694}, {'x': 0.1129, 'y': 3.694}]}
# page_content='<br><p id='36' data-category='paragraph' style='font-size:16px'>实战任务</p>' metadata={'id': 36, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.6024}, {'x': 0.187, 'y': 3.6024}, {'x': 0.187, 'y': 3.6173}, {'x': 0.1129, 'y': 3.6173}]}
# page_content='<p id='37' data-category='paragraph' style='font-size:16px'>实战任务</p>' metadata={'id': 37, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.8716}, {'x': 0.187, 'y': 3.8716}, {'x': 0.187, 'y': 3.8866}, {'x': 0.1129, 'y': 3.8866}]}
# page_content='<br><p id='38' data-category='paragraph' style='font-size:16px'>AI Agent</p>' metadata={'id': 38, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.128, 'y': 2.8783}, {'x': 0.1982, 'y': 2.8783}, {'x': 0.1982, 'y': 2.8933}, {'x': 0.128, 'y': 2.8933}]}
# page_content='<p id='39' data-category='paragraph' style='font-size:16px'>频考点与实战能力，确保面试时具备技术深度与项目经验双重竞争力。</p>' metadata={'id': 39, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.229}, {'x': 0.6431, 'y': 3.229}, {'x': 0.6431, 'y': 3.2439}, {'x': 0.0927, 'y': 3.2439}]}
# page_content='<p id='40' data-category='paragraph' style='font-size:18px'>▍第一阶段：基础巩固（第 天）</p>' metadata={'id': 40, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0925, 'y': 3.72}, {'x': 0.4138, 'y': 3.72}, {'x': 0.4138, 'y': 3.7371}, {'x': 0.0925, 'y': 3.7371}]}
# page_content='<h1 id='41' style='font-size:20px'>一、学习总览与时间分配</h1>' metadata={'id': 41, 'page': 1, 'category': 'heading1', 'coordinates': [{'x': 0.092, 'y': 4.3958}, {'x': 0.3779, 'y': 4.3958}, {'x': 0.3779, 'y': 4.4172}, {'x': 0.092, 'y': 4.4172}]}
# page_content='<h1 id='42' style='font-size:20px'>二、每日学习计划与核心内容</h1>' metadata={'id': 42, 'page': 1, 'category': 'heading1', 'coordinates': [{'x': 0.092, 'y': 4.5243}, {'x': 0.429, 'y': 4.5243}, {'x': 0.429, 'y': 4.5457}, {'x': 0.092, 'y': 4.5457}]}
# page_content='<br><p id='43' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 43, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.6273}, {'x': 0.1125, 'y': 3.6273}, {'x': 0.1125, 'y': 3.6423}, {'x': 0.0914, 'y': 3.6423}]}
# page_content='<br><p id='44' data-category='paragraph' style='font-size:16px'>天划分为</p>' metadata={'id': 44, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.2073}, {'x': 0.1668, 'y': 3.2073}, {'x': 0.1668, 'y': 3.2223}, {'x': 0.0927, 'y': 3.2223}]}
# page_content='<p id='45' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 45, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.7039}, {'x': 0.1125, 'y': 3.7039}, {'x': 0.1125, 'y': 3.7189}, {'x': 0.0914, 'y': 3.7189}]}
# page_content='<br><p id='46' data-category='paragraph' style='font-size:16px'>第 天：</p>' metadata={'id': 46, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.3729}, {'x': 0.1601, 'y': 3.3729}, {'x': 0.1601, 'y': 3.3878}, {'x': 0.0927, 'y': 3.3878}]}
# page_content='<p id='47' data-category='paragraph' style='font-size:16px'>第 天：</p>' metadata={'id': 47, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.6425}, {'x': 0.1601, 'y': 3.6425}, {'x': 0.1601, 'y': 3.6575}, {'x': 0.0927, 'y': 3.6575}]}
# page_content='<br><p id='48' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 48, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.5434}, {'x': 0.1125, 'y': 3.5434}, {'x': 0.1125, 'y': 3.5584}, {'x': 0.0914, 'y': 3.5584}]}
# page_content='<p id='49' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 49, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.8127}, {'x': 0.1125, 'y': 3.8127}, {'x': 0.1125, 'y': 3.8277}, {'x': 0.0914, 'y': 3.8277}]}
# page_content='<br><p id='50' data-category='paragraph' style='font-size:16px'>目标</p>' metadata={'id': 50, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.3327}, {'x': 0.1315, 'y': 3.3327}, {'x': 0.1315, 'y': 3.3477}, {'x': 0.0927, 'y': 3.3477}]}
# page_content='<p id='51' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 51, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.4343}, {'x': 0.1125, 'y': 3.4343}, {'x': 0.1125, 'y': 3.4492}, {'x': 0.0914, 'y': 3.4492}]}
# page_content='<br><p id='52' data-category='paragraph' style='font-size:16px'>根据</p>' metadata={'id': 52, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.1857}, {'x': 0.1315, 'y': 3.1857}, {'x': 0.1315, 'y': 3.2006}, {'x': 0.0927, 'y': 3.2006}]}
# page_content='<h1 id='53' style='font-size:22px'>15 AI Agent</h1>' metadata={'id': 53, 'page': 1, 'category': 'heading1', 'coordinates': [{'x': 0.0917, 'y': 4.3263}, {'x': 0.2723, 'y': 4.3263}, {'x': 0.2723, 'y': 4.3498}, {'x': 0.0917, 'y': 4.3498}]}
# page_content='<br><p id='54' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 54, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.8965}, {'x': 0.1125, 'y': 3.8965}, {'x': 0.1125, 'y': 3.9115}, {'x': 0.0914, 'y': 3.9115}]}
# page_content='<br><p id='55' data-category='paragraph' style='font-size:16px'>Python</p>' metadata={'id': 55, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.3711, 'y': 2.8783}, {'x': 0.4295, 'y': 2.8783}, {'x': 0.4295, 'y': 2.8933}, {'x': 0.3711, 'y': 2.8933}]}
# page_content='<p id='56' data-category='paragraph' style='font-size:16px'>基础与</p>' metadata={'id': 56, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.3231, 'y': 3.3578}, {'x': 0.3795, 'y': 3.3578}, {'x': 0.3795, 'y': 3.3727}, {'x': 0.3231, 'y': 3.3727}]}
# page_content='<br><p id='57' data-category='paragraph' style='font-size:16px'>LLM</p>' metadata={'id': 57, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.2888, 'y': 3.0504}, {'x': 0.3266, 'y': 3.0504}, {'x': 0.3266, 'y': 3.0654}, {'x': 0.2888, 'y': 3.0654}]}
# page_content='<p id='58' data-category='paragraph' style='font-size:22px'>工程师面试学习路线</p>' metadata={'id': 58, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.2672, 'y': 4.7699}, {'x': 0.525, 'y': 4.7699}, {'x': 0.525, 'y': 4.7934}, {'x': 0.2672, 'y': 4.7934}]}
# page_content='<br><p id='59' data-category='paragraph' style='font-size:16px'>库、协程与任务调度）</p>' metadata={'id': 59, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.3046, 'y': 3.4843}, {'x': 0.4845, 'y': 3.4843}, {'x': 0.4845, 'y': 3.4992}, {'x': 0.3046, 'y': 3.4992}]}
# page_content='<br><p id='60' data-category='paragraph' style='font-size:18px'>1-3</p>' metadata={'id': 60, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.3389, 'y': 3.3974}, {'x': 0.3728, 'y': 3.3974}, {'x': 0.3728, 'y': 3.4145}, {'x': 0.3389, 'y': 3.4145}]}
# page_content='<br><p id='61' data-category='paragraph' style='font-size:16px'>Prompt Engineering</p>' metadata={'id': 61, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.376, 'y': 3.0504}, {'x': 0.5354, 'y': 3.0504}, {'x': 0.5354, 'y': 3.0654}, {'x': 0.376, 'y': 3.0654}]}
# page_content='<p id='62' data-category='paragraph' style='font-size:16px'>编程、 应用、</p>' metadata={'id': 62, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.426, 'y': 3.1857}, {'x': 0.5697, 'y': 3.1857}, {'x': 0.5697, 'y': 3.2006}, {'x': 0.426, 'y': 3.2006}]}
# page_content='<br><p id='63' data-category='paragraph' style='font-size:16px'>LLM</p>' metadata={'id': 63, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.4789, 'y': 2.8783}, {'x': 0.5168, 'y': 2.8783}, {'x': 0.5168, 'y': 2.8933}, {'x': 0.4789, 'y': 2.8933}]}
# page_content='<p id='64' data-category='paragraph' style='font-size:16px'>，为</p>' metadata={'id': 64, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.5319, 'y': 3.3578}, {'x': 0.5707, 'y': 3.3578}, {'x': 0.5707, 'y': 3.3727}, {'x': 0.5319, 'y': 3.3727}]}
# page_content='<br><p id='65' data-category='paragraph' style='font-size:16px'>开发铺垫底层能力。</p>' metadata={'id': 65, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.6132, 'y': 3.3578}, {'x': 0.7755, 'y': 3.3578}, {'x': 0.7755, 'y': 3.3727}, {'x': 0.6132, 'y': 3.3727}]}
# page_content='<br><p id='66' data-category='paragraph' style='font-size:16px'>框架、</p>' metadata={'id': 66, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.6122, 'y': 3.1857}, {'x': 0.6687, 'y': 3.1857}, {'x': 0.6687, 'y': 3.2006}, {'x': 0.6122, 'y': 3.2006}]}
# page_content='<br><p id='67' data-category='paragraph' style='font-size:16px'>RAG</p>' metadata={'id': 67, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.6651, 'y': 2.8783}, {'x': 0.7069, 'y': 2.8783}, {'x': 0.7069, 'y': 2.8933}, {'x': 0.6651, 'y': 2.8933}]}
# page_content='<p id='68' data-category='paragraph' style='font-size:16px'>系统、工具集成），将</p>' metadata={'id': 68, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.7034, 'y': 3.1857}, {'x': 0.8833, 'y': 3.1857}, {'x': 0.8833, 'y': 3.2006}, {'x': 0.7034, 'y': 3.2006}]}
# page_content='<br><p id='69' data-category='paragraph' style='font-size:16px'>Agent</p>' metadata={'id': 69, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.5671, 'y': 3.0504}, {'x': 0.6167, 'y': 3.0504}, {'x': 0.6167, 'y': 3.0654}, {'x': 0.5671, 'y': 3.0654}]}
# page_content='<br><p id='70' data-category='paragraph' style='font-size:16px'>Agent</p>' metadata={'id': 70, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.5661, 'y': 2.8783}, {'x': 0.6158, 'y': 2.8783}, {'x': 0.6158, 'y': 2.8933}, {'x': 0.5661, 'y': 2.8933}]}
# page_content='<p id='71' data-category='paragraph' style='font-size:16px'>四个阶段，聚焦高</p>' metadata={'id': 71, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.7519, 'y': 3.2073}, {'x': 0.8965, 'y': 3.2073}, {'x': 0.8965, 'y': 3.2223}, {'x': 0.7519, 'y': 3.2223}]}
# page_content='<br><p id='72' data-category='paragraph' style='font-size:16px'>15</p>' metadata={'id': 72, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.8798, 'y': 2.8783}, {'x': 0.9029, 'y': 2.8783}, {'x': 0.9029, 'y': 2.8933}, {'x': 0.8798, 'y': 2.8933}]}
# page_content='<p id='73' data-category='paragraph' style='font-size:14px'>1/8</p>' metadata={'id': 73, 'page': 1, 'category': 'paragraph', 'coordinates': [{'x': 0.8829, 'y': 3.5161}, {'x': 0.907, 'y': 3.5161}, {'x': 0.907, 'y': 3.529}, {'x': 0.8829, 'y': 3.529}]}
# page_content='<p id='74' data-category='paragraph' style='font-size:14px'>2/8</p>' metadata={'id': 74, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.8825, 'y': 3.5161}, {'x': 0.907, 'y': 3.5161}, {'x': 0.907, 'y': 3.529}, {'x': 0.8825, 'y': 3.529}]}
# page_content='<br><p id='75' data-category='list'></p>' metadata={'id': 75, 'page': 2, 'category': 'list', 'coordinates': [{'x': 0.115, 'y': 0.1369}, {'x': 0.6925, 'y': 0.1369}, {'x': 0.6925, 'y': 0.2047}, {'x': 0.115, 'y': 0.2047}]}
# page_content='<p id='76' data-category='list'></p>' metadata={'id': 76, 'page': 2, 'category': 'list', 'coordinates': [{'x': 0.1144, 'y': 0.2458}, {'x': 0.7687, 'y': 0.2458}, {'x': 0.7687, 'y': 0.2885}, {'x': 0.1144, 'y': 0.2885}]}
# page_content='<p id='77' data-category='list'></p>' metadata={'id': 77, 'page': 2, 'category': 'list', 'coordinates': [{'x': 0.1139, 'y': 0.4851}, {'x': 0.8754, 'y': 0.4851}, {'x': 0.8754, 'y': 0.5536}, {'x': 0.1139, 'y': 0.5536}]}
# page_content='<p id='78' data-category='list'></p>' metadata={'id': 78, 'page': 2, 'category': 'list', 'coordinates': [{'x': 0.1148, 'y': 0.5932}, {'x': 0.6559, 'y': 0.5932}, {'x': 0.6559, 'y': 0.6379}, {'x': 0.1148, 'y': 0.6379}]}
# page_content='<p id='79' data-category='paragraph' style='font-size:14px'>ConversationSummaryMemory</p>' metadata={'id': 79, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.6271, 'y': 3.3377}, {'x': 0.8558, 'y': 3.3377}, {'x': 0.8558, 'y': 3.3505}, {'x': 0.6271, 'y': 3.3505}]}
# page_content='<p id='80' data-category='paragraph' style='font-size:16px'>（对</p>' metadata={'id': 80, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.8626, 'y': 3.7891}, {'x': 0.9014, 'y': 3.7891}, {'x': 0.9014, 'y': 3.8041}, {'x': 0.8626, 'y': 3.8041}]}
# page_content='<br><p id='81' data-category='paragraph' style='font-size:16px'>第 天：</p>' metadata={'id': 81, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.4117}, {'x': 0.1601, 'y': 3.4117}, {'x': 0.1601, 'y': 3.4266}, {'x': 0.0927, 'y': 3.4266}]}
# page_content='<br><p id='82' data-category='paragraph' style='font-size:16px'>第 天：</p>' metadata={'id': 82, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.0628}, {'x': 0.1601, 'y': 3.0628}, {'x': 0.1601, 'y': 3.0778}, {'x': 0.0927, 'y': 3.0778}]}
# page_content='<p id='83' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 83, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.3169}, {'x': 0.1125, 'y': 3.3169}, {'x': 0.1125, 'y': 3.3318}, {'x': 0.0914, 'y': 3.3318}]}
# page_content='<br><p id='84' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 84, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.233}, {'x': 0.1125, 'y': 3.233}, {'x': 0.1125, 'y': 3.248}, {'x': 0.0914, 'y': 3.248}]}
# page_content='<p id='85' data-category='paragraph' style='font-size:18px'>• ▍第二阶段：核心技术（第</p>' metadata={'id': 85, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0907, 'y': 3.7585}, {'x': 0.343, 'y': 3.7585}, {'x': 0.343, 'y': 3.7795}, {'x': 0.0907, 'y': 3.7795}]}
# page_content='<br><p id='86' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 86, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.1242}, {'x': 0.1125, 'y': 3.1242}, {'x': 0.1125, 'y': 3.1392}, {'x': 0.0914, 'y': 3.1392}]}
# page_content='<p id='87' data-category='paragraph' style='font-size:16px'>目标</p>' metadata={'id': 87, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.3715}, {'x': 0.1315, 'y': 3.3715}, {'x': 0.1315, 'y': 3.3865}, {'x': 0.0927, 'y': 3.3865}]}
# page_content='<p id='88' data-category='paragraph' style='font-size:16px'>第 天：</p>' metadata={'id': 88, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.7027}, {'x': 0.1601, 'y': 3.7027}, {'x': 0.1601, 'y': 3.7176}, {'x': 0.0927, 'y': 3.7176}]}
# page_content='<br><p id='89' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 89, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.4731}, {'x': 0.1125, 'y': 3.4731}, {'x': 0.1125, 'y': 3.488}, {'x': 0.0914, 'y': 3.488}]}
# page_content='<p id='90' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 90, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.6661}, {'x': 0.1125, 'y': 3.6661}, {'x': 0.1125, 'y': 3.681}, {'x': 0.0914, 'y': 3.681}]}
# page_content='<br><p id='91' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 91, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.5818}, {'x': 0.1125, 'y': 3.5818}, {'x': 0.1125, 'y': 3.5968}, {'x': 0.0914, 'y': 3.5968}]}
# page_content='<p id='92' data-category='paragraph' style='font-size:16px'>记忆机制</p>' metadata={'id': 92, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.2087, 'y': 3.7027}, {'x': 0.2839, 'y': 3.7027}, {'x': 0.2839, 'y': 3.7176}, {'x': 0.2087, 'y': 3.7176}]}
# page_content='<br><p id='93' data-category='paragraph' style='font-size:16px'>：掌握</p>' metadata={'id': 93, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.128, 'y': 3.3965}, {'x': 0.1845, 'y': 3.3965}, {'x': 0.1845, 'y': 3.4115}, {'x': 0.128, 'y': 3.4115}]}
# page_content='<p id='94' data-category='paragraph' style='font-size:16px'>话摘要）</p>' metadata={'id': 94, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.133, 'y': 3.8109}, {'x': 0.2071, 'y': 3.8109}, {'x': 0.2071, 'y': 3.8259}, {'x': 0.133, 'y': 3.8259}]}
# page_content='<br><p id='95' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 95, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.2331}, {'x': 0.2046, 'y': 3.2331}, {'x': 0.2046, 'y': 3.2481}, {'x': 0.1834, 'y': 3.2481}]}
# page_content='<br><p id='96' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 96, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.1243}, {'x': 0.2046, 'y': 3.1243}, {'x': 0.2046, 'y': 3.1393}, {'x': 0.1834, 'y': 3.1393}]}
# page_content='<p id='97' data-category='paragraph' style='font-size:16px'>◦ 论文《ReAct: Synergizing Reasoning and Acting in Language Models》（核心摘要）</p>' metadata={'id': 97, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.2564}, {'x': 0.7741, 'y': 3.2564}, {'x': 0.7741, 'y': 3.2732}, {'x': 0.1168, 'y': 3.2732}]}
# page_content='<br><p id='98' data-category='paragraph' style='font-size:16px'>学习资源</p>' metadata={'id': 98, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.2081}, {'x': 0.187, 'y': 3.2081}, {'x': 0.187, 'y': 3.2231}, {'x': 0.1129, 'y': 3.2231}]}
# page_content='<br><p id='99' data-category='paragraph' style='font-size:16px'>◦ 常见提示词模板（任务拆解、错误修正、角色模拟）</p>' metadata={'id': 99, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1975}, {'x': 0.5425, 'y': 3.1975}, {'x': 0.5425, 'y': 3.2143}, {'x': 0.1168, 'y': 3.2143}]}
# page_content='<p id='100' data-category='paragraph' style='font-size:16px'>实战任务</p>' metadata={'id': 100, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.292}, {'x': 0.187, 'y': 3.292}, {'x': 0.187, 'y': 3.3069}, {'x': 0.1129, 'y': 3.3069}]}
# page_content='<br><p id='101' data-category='paragraph' style='font-size:16px'>◦ LangChain Prompt模板文档（LangChain Prompts）</p>' metadata={'id': 101, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.2814}, {'x': 0.5303, 'y': 3.2814}, {'x': 0.5303, 'y': 3.2981}, {'x': 0.1168, 'y': 3.2981}]}
# page_content='<p id='102' data-category='paragraph' style='font-size:16px'>◦ GitHub项目：</p>' metadata={'id': 102, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.6302}, {'x': 0.2431, 'y': 3.6302}, {'x': 0.2431, 'y': 3.647}, {'x': 0.1168, 'y': 3.647}]}
# page_content='<br><p id='103' data-category='paragraph' style='font-size:16px'>◦ 思维链（Chain-of-Thought, CoT）：分步推理提示设计</p>' metadata={'id': 103, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1476}, {'x': 0.5617, 'y': 3.1476}, {'x': 0.5617, 'y': 3.1644}, {'x': 0.1168, 'y': 3.1644}]}
# page_content='<br><p id='104' data-category='paragraph' style='font-size:16px'>核心内容</p>' metadata={'id': 104, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.0993}, {'x': 0.187, 'y': 3.0993}, {'x': 0.187, 'y': 3.1143}, {'x': 0.1129, 'y': 3.1143}]}
# page_content='<br><p id='105' data-category='paragraph' style='font-size:16px'>Agent</p>' metadata={'id': 105, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1809, 'y': 3.0892}, {'x': 0.2305, 'y': 3.0892}, {'x': 0.2305, 'y': 3.1042}, {'x': 0.1809, 'y': 3.1042}]}
# page_content='<p id='106' data-category='paragraph' style='font-size:16px'>◦ ReAct框架基础：推理（Reason）→行动（Act）→观察（Observe）循环</p>' metadata={'id': 106, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1726}, {'x': 0.692, 'y': 3.1726}, {'x': 0.692, 'y': 3.1894}, {'x': 0.1168, 'y': 3.1894}]}
# page_content='<p id='107' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 107, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.4732}, {'x': 0.2046, 'y': 3.4732}, {'x': 0.2046, 'y': 3.4881}, {'x': 0.1834, 'y': 3.4881}]}
# page_content='<p id='108' data-category='paragraph' style='font-size:16px'>具添加日程）</p>' metadata={'id': 108, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.6876}, {'x': 0.2222, 'y': 3.6876}, {'x': 0.2222, 'y': 3.7025}, {'x': 0.1129, 'y': 3.7025}]}
# page_content='<br><p id='109' data-category='paragraph' style='font-size:16px'>◦ LCEL（LangChain Expression Language）基础语法</p>' metadata={'id': 109, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.5214}, {'x': 0.5212, 'y': 3.5214}, {'x': 0.5212, 'y': 3.5382}, {'x': 0.1168, 'y': 3.5382}]}
# page_content='<p id='110' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 110, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.582}, {'x': 0.2046, 'y': 3.582}, {'x': 0.2046, 'y': 3.5969}, {'x': 0.1834, 'y': 3.5969}]}
# page_content='<br><p id='111' data-category='paragraph' style='font-size:16px'>◦ LangChain官方快速入门（LangChain Quickstart）</p>' metadata={'id': 111, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.6052}, {'x': 0.5191, 'y': 3.6052}, {'x': 0.5191, 'y': 3.622}, {'x': 0.1168, 'y': 3.622}]}
# page_content='<p id='112' data-category='paragraph' style='font-size:16px'>◦ 短期记忆：</p>' metadata={'id': 112, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.7875}, {'x': 0.225, 'y': 3.7875}, {'x': 0.225, 'y': 3.8042}, {'x': 0.1168, 'y': 3.8042}]}
# page_content='<br><p id='113' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 113, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.7642}, {'x': 0.2046, 'y': 3.7642}, {'x': 0.2046, 'y': 3.7791}, {'x': 0.1834, 'y': 3.7791}]}
# page_content='<br><p id='114' data-category='paragraph' style='font-size:16px'>4</p>' metadata={'id': 114, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1115, 'y': 3.1299}, {'x': 0.1233, 'y': 3.1299}, {'x': 0.1233, 'y': 3.1438}, {'x': 0.1115, 'y': 3.1438}]}
# page_content='<p id='115' data-category='paragraph' style='font-size:16px'>核心内容</p>' metadata={'id': 115, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.4481}, {'x': 0.187, 'y': 3.4481}, {'x': 0.187, 'y': 3.4631}, {'x': 0.1129, 'y': 3.4631}]}
# page_content='<p id='116' data-category='paragraph' style='font-size:16px'>实战任务</p>' metadata={'id': 116, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.6412}, {'x': 0.187, 'y': 3.6412}, {'x': 0.187, 'y': 3.6561}, {'x': 0.1129, 'y': 3.6561}]}
# page_content='<br><p id='117' data-category='paragraph' style='font-size:16px'>学习资源</p>' metadata={'id': 117, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.5569}, {'x': 0.187, 'y': 3.5569}, {'x': 0.187, 'y': 3.5719}, {'x': 0.1129, 'y': 3.5719}]}
# page_content='<br><p id='118' data-category='paragraph' style='font-size:16px'>◦ 简单Agent构建流程（初始化LLM→定义工具→创建Agent→运行任务）</p>' metadata={'id': 118, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.5463}, {'x': 0.6823, 'y': 3.5463}, {'x': 0.6823, 'y': 3.5631}, {'x': 0.1168, 'y': 3.5631}]}
# page_content='<br><p id='119' data-category='paragraph' style='font-size:16px'>3</p>' metadata={'id': 119, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1115, 'y': 2.7811}, {'x': 0.1233, 'y': 2.7811}, {'x': 0.1233, 'y': 2.7949}, {'x': 0.1115, 'y': 2.7949}]}
# page_content='<p id='120' data-category='paragraph' style='font-size:16px'>◦ 长期记忆：向量数据库原理（Embedding生成、相似性检索）</p>' metadata={'id': 120, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.8342}, {'x': 0.6117, 'y': 3.8342}, {'x': 0.6117, 'y': 3.851}, {'x': 0.1168, 'y': 3.851}]}
# page_content='<br><p id='121' data-category='paragraph' style='font-size:16px'>◦ LangChain核心组件：Chains（任务链）、Tools（工具）、Memory（记忆）、Agents（智能体）</p>' metadata={'id': 121, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.4965}, {'x': 0.8813, 'y': 3.4965}, {'x': 0.8813, 'y': 3.5132}, {'x': 0.1168, 'y': 3.5132}]}
# page_content='<p id='122' data-category='paragraph' style='font-size:16px'>核心内容</p>' metadata={'id': 122, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.7392}, {'x': 0.187, 'y': 3.7392}, {'x': 0.187, 'y': 3.7541}, {'x': 0.1129, 'y': 3.7541}]}
# page_content='<p id='123' data-category='paragraph' style='font-size:16px'>◦ 记忆设计模式：Memory Stack（短期+长期记忆结合）</p>' metadata={'id': 123, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.8591}, {'x': 0.552, 'y': 3.8591}, {'x': 0.552, 'y': 3.8759}, {'x': 0.1168, 'y': 3.8759}]}
# page_content='<br><p id='124' data-category='paragraph' style='font-size:16px'>5</p>' metadata={'id': 124, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1115, 'y': 3.4209}, {'x': 0.1233, 'y': 3.4209}, {'x': 0.1233, 'y': 3.4348}, {'x': 0.1115, 'y': 3.4348}]}
# page_content='<br><p id='125' data-category='paragraph' style='font-size:16px'>框架、记忆系统、工具集成与</p>' metadata={'id': 125, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.227, 'y': 3.3965}, {'x': 0.4598, 'y': 3.3965}, {'x': 0.4598, 'y': 3.4115}, {'x': 0.227, 'y': 3.4115}]}
# page_content='<br><p id='126' data-category='paragraph' style='font-size:16px'>框架入门</p>' metadata={'id': 126, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.2514, 'y': 3.4117}, {'x': 0.3266, 'y': 3.4117}, {'x': 0.3266, 'y': 3.4266}, {'x': 0.2514, 'y': 3.4266}]}
# page_content='<br><p id='127' data-category='paragraph' style='font-size:14px'>ConversationBufferMemory</p>' metadata={'id': 127, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.2316, 'y': 3.3377}, {'x': 0.4512, 'y': 3.3377}, {'x': 0.4512, 'y': 3.3505}, {'x': 0.2316, 'y': 3.3505}]}
# page_content='<p id='128' data-category='paragraph' style='font-size:16px'>：使用LangChain构建一个"天气+日历"多工具Agent（调用天气API查询天气，调用本地日历工</p>' metadata={'id': 128, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.6662}, {'x': 0.9061, 'y': 3.6662}, {'x': 0.9061, 'y': 3.6812}, {'x': 0.1834, 'y': 3.6812}]}
# page_content='<br><p id='129' data-category='paragraph' style='font-size:16px'>Prompt Engineering</p>' metadata={'id': 129, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1569, 'y': 2.7805}, {'x': 0.3353, 'y': 2.7805}, {'x': 0.3353, 'y': 2.7955}, {'x': 0.1569, 'y': 2.7955}]}
# page_content='<p id='130' data-category='paragraph' style='font-size:16px'>LangChain</p>' metadata={'id': 130, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1569, 'y': 3.1294}, {'x': 0.2546, 'y': 3.1294}, {'x': 0.2546, 'y': 3.1443}, {'x': 0.1569, 'y': 3.1443}]}
# page_content='<p id='131' data-category='paragraph' style='font-size:16px'>：设计一个数学解题Agent提示词（使用CoT让模型分步计算复杂数学题）</p>' metadata={'id': 131, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.317}, {'x': 0.7557, 'y': 3.317}, {'x': 0.7557, 'y': 3.3319}, {'x': 0.1834, 'y': 3.3319}]}
# page_content='<p id='132' data-category='paragraph' style='font-size:16px'>Agent</p>' metadata={'id': 132, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.1569, 'y': 3.4204}, {'x': 0.2119, 'y': 3.4204}, {'x': 0.2119, 'y': 3.4353}, {'x': 0.1569, 'y': 3.4353}]}
# page_content='<br><p id='133' data-category='paragraph' style='font-size:14px'>langchain-ai/langchain</p>' metadata={'id': 133, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.2497, 'y': 3.1805}, {'x': 0.4513, 'y': 3.1805}, {'x': 0.4513, 'y': 3.1932}, {'x': 0.2497, 'y': 3.1932}]}
# page_content='<p id='134' data-category='paragraph' style='font-size:20px'>天）</p>' metadata={'id': 134, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.3807, 'y': 3.7588}, {'x': 0.4254, 'y': 3.7588}, {'x': 0.4254, 'y': 3.7759}, {'x': 0.3807, 'y': 3.7759}]}
# page_content='<br><p id='135' data-category='paragraph' style='font-size:16px'>进阶</p>' metadata={'id': 135, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.3322, 'y': 3.0628}, {'x': 0.3713, 'y': 3.0628}, {'x': 0.3713, 'y': 3.0778}, {'x': 0.3322, 'y': 3.0778}]}
# page_content='<p id='136' data-category='paragraph' style='font-size:20px'>4-10</p>' metadata={'id': 136, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.3389, 'y': 3.4362}, {'x': 0.3844, 'y': 3.4362}, {'x': 0.3844, 'y': 3.4533}, {'x': 0.3389, 'y': 3.4533}]}
# page_content='<br><p id='137' data-category='list'></p>' metadata={'id': 137, 'page': 2, 'category': 'list', 'coordinates': [{'x': 0.1155, 'y': 0.775}, {'x': 0.9012, 'y': 0.775}, {'x': 0.9012, 'y': 0.8663}, {'x': 0.1155, 'y': 0.8663}]}
# page_content='<p id='138' data-category='paragraph' style='font-size:16px'>RAG</p>' metadata={'id': 138, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.4563, 'y': 3.0892}, {'x': 0.4981, 'y': 3.0892}, {'x': 0.4981, 'y': 3.1042}, {'x': 0.4563, 'y': 3.1042}]}
# page_content='<p id='139' data-category='paragraph' style='font-size:16px'>（examples/agents目录）</p>' metadata={'id': 139, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.4581, 'y': 3.6318}, {'x': 0.6611, 'y': 3.6318}, {'x': 0.6611, 'y': 3.6468}, {'x': 0.4581, 'y': 3.6468}]}
# page_content='<br><p id='140' data-category='paragraph' style='font-size:16px'>技术，构建完整</p>' metadata={'id': 140, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.4945, 'y': 3.3965}, {'x': 0.6215, 'y': 3.3965}, {'x': 0.6215, 'y': 3.4115}, {'x': 0.4945, 'y': 3.4115}]}
# page_content='<p id='141' data-category='paragraph' style='font-size:16px'>（对话历史管理）、</p>' metadata={'id': 141, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.458, 'y': 3.7891}, {'x': 0.6203, 'y': 3.7891}, {'x': 0.6203, 'y': 3.8041}, {'x': 0.458, 'y': 3.8041}]}
# page_content='<br><p id='142' data-category='paragraph' style='font-size:16px'>Agent</p>' metadata={'id': 142, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.618, 'y': 3.0892}, {'x': 0.6676, 'y': 3.0892}, {'x': 0.6676, 'y': 3.1042}, {'x': 0.618, 'y': 3.1042}]}
# page_content='<p id='143' data-category='paragraph' style='font-size:16px'>能力栈。</p>' metadata={'id': 143, 'page': 2, 'category': 'paragraph', 'coordinates': [{'x': 0.6641, 'y': 3.3965}, {'x': 0.7382, 'y': 3.3965}, {'x': 0.7382, 'y': 3.4115}, {'x': 0.6641, 'y': 3.4115}]}
# page_content='<p id='144' data-category='list'></p>' metadata={'id': 144, 'page': 3, 'category': 'list', 'coordinates': [{'x': 0.1144, 'y': 0.1031}, {'x': 0.531, 'y': 0.1031}, {'x': 0.531, 'y': 0.1456}, {'x': 0.1144, 'y': 0.1456}]}
# page_content='<p id='145' data-category='list'></p>' metadata={'id': 145, 'page': 3, 'category': 'list', 'coordinates': [{'x': 0.1143, 'y': 0.2844}, {'x': 0.7361, 'y': 0.2844}, {'x': 0.7361, 'y': 0.3529}, {'x': 0.1143, 'y': 0.3529}]}
# page_content='<p id='146' data-category='list'></p>' metadata={'id': 146, 'page': 3, 'category': 'list', 'coordinates': [{'x': 0.117, 'y': 0.3939}, {'x': 0.4477, 'y': 0.3939}, {'x': 0.4477, 'y': 0.4093}, {'x': 0.117, 'y': 0.4093}]}
# page_content='<p id='147' data-category='list'></p>' metadata={'id': 147, 'page': 3, 'category': 'list', 'coordinates': [{'x': 0.1163, 'y': 0.4189}, {'x': 0.5456, 'y': 0.4189}, {'x': 0.5456, 'y': 0.4358}, {'x': 0.1163, 'y': 0.4358}]}
# page_content='<p id='148' data-category='list'></p>' metadata={'id': 148, 'page': 3, 'category': 'list', 'coordinates': [{'x': 0.1139, 'y': 0.5757}, {'x': 0.8558, 'y': 0.5757}, {'x': 0.8558, 'y': 0.645}, {'x': 0.1139, 'y': 0.645}]}
# page_content='<p id='149' data-category='paragraph' style='font-size:14px'>3/8</p>' metadata={'id': 149, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.8825, 'y': 3.5161}, {'x': 0.907, 'y': 3.5161}, {'x': 0.907, 'y': 3.529}, {'x': 0.8825, 'y': 3.529}]}
# page_content='<br><p id='150' data-category='list'></p>' metadata={'id': 150, 'page': 3, 'category': 'list', 'coordinates': [{'x': 0.1153, 'y': 0.6845}, {'x': 0.4576, 'y': 0.6845}, {'x': 0.4576, 'y': 0.7283}, {'x': 0.1153, 'y': 0.7283}]}
# page_content='<p id='151' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 151, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.8544}, {'x': 0.1125, 'y': 3.8544}, {'x': 0.1125, 'y': 3.8693}, {'x': 0.0914, 'y': 3.8693}]}
# page_content='<br><p id='152' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 152, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.6725}, {'x': 0.1125, 'y': 3.6725}, {'x': 0.1125, 'y': 3.6875}, {'x': 0.0914, 'y': 3.6875}]}
# page_content='<p id='153' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 153, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.7564}, {'x': 0.1125, 'y': 3.7564}, {'x': 0.1125, 'y': 3.7713}, {'x': 0.0914, 'y': 3.7713}]}
# page_content='<p id='154' data-category='paragraph' style='font-size:18px'>第 天：多</p>' metadata={'id': 154, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.793}, {'x': 0.1781, 'y': 3.793}, {'x': 0.1781, 'y': 3.8079}, {'x': 0.0927, 'y': 3.8079}]}
# page_content='<br><p id='155' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 155, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.3811}, {'x': 0.1125, 'y': 3.3811}, {'x': 0.1125, 'y': 3.3961}, {'x': 0.0914, 'y': 3.3961}]}
# page_content='<br><p id='156' data-category='paragraph' style='font-size:18px'>第 天：</p>' metadata={'id': 156, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.2109}, {'x': 0.1601, 'y': 3.2109}, {'x': 0.1601, 'y': 3.2259}, {'x': 0.0927, 'y': 3.2259}]}
# page_content='<p id='157' data-category='paragraph' style='font-size:18px'>第 天：工具调用与外部集成</p>' metadata={'id': 157, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0927, 'y': 3.502}, {'x': 0.3222, 'y': 3.502}, {'x': 0.3222, 'y': 3.5169}, {'x': 0.0927, 'y': 3.5169}]}
# page_content='<br><p id='158' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 158, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.2723}, {'x': 0.1125, 'y': 3.2723}, {'x': 0.1125, 'y': 3.2873}, {'x': 0.0914, 'y': 3.2873}]}
# page_content='<br><p id='159' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 159, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.1743}, {'x': 0.1125, 'y': 3.1743}, {'x': 0.1125, 'y': 3.1893}, {'x': 0.0914, 'y': 3.1893}]}
# page_content='<p id='160' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 160, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.4654}, {'x': 0.1125, 'y': 3.4654}, {'x': 0.1125, 'y': 3.4803}, {'x': 0.0914, 'y': 3.4803}]}
# page_content='<br><p id='161' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 161, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.0905}, {'x': 0.1125, 'y': 3.0905}, {'x': 0.1125, 'y': 3.1055}, {'x': 0.0914, 'y': 3.1055}]}
# page_content='<p id='162' data-category='paragraph' style='font-size:18px'>•</p>' metadata={'id': 162, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.5634}, {'x': 0.1125, 'y': 3.5634}, {'x': 0.1125, 'y': 3.5783}, {'x': 0.0914, 'y': 3.5783}]}
# page_content='<br><p id='163' data-category='paragraph' style='font-size:14px'>Tool</p>' metadata={'id': 163, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.2669, 'y': 3.137}, {'x': 0.306, 'y': 3.137}, {'x': 0.306, 'y': 3.1497}, {'x': 0.2669, 'y': 3.1497}]}
# page_content='<p id='164' data-category='paragraph' style='font-size:18px'>协作框架</p>' metadata={'id': 164, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.2268, 'y': 3.793}, {'x': 0.3019, 'y': 3.793}, {'x': 0.3019, 'y': 3.8079}, {'x': 0.2268, 'y': 3.8079}]}
# page_content='<br><p id='165' data-category='paragraph' style='font-size:14px'>langchain-ai/rag-example</p>' metadata={'id': 165, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.2316, 'y': 2.9797}, {'x': 0.4512, 'y': 2.9797}, {'x': 0.4512, 'y': 2.9925}, {'x': 0.2316, 'y': 2.9925}]}
# page_content='<p id='166' data-category='paragraph' style='font-size:18px'>系统核心技术</p>' metadata={'id': 166, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1972, 'y': 3.2109}, {'x': 0.3084, 'y': 3.2109}, {'x': 0.3084, 'y': 3.2259}, {'x': 0.1972, 'y': 3.2259}]}
# page_content='<br><p id='167' data-category='paragraph' style='font-size:18px'>：实现一个带长期记忆的聊天Agent（使用Chroma存储历史对话，支持检索过去3轮对话内</p>' metadata={'id': 167, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.1744}, {'x': 0.8835, 'y': 3.1744}, {'x': 0.8835, 'y': 3.1894}, {'x': 0.1834, 'y': 3.1894}]}
# page_content='<p id='168' data-category='paragraph' style='font-size:18px'>：构建一个PDF文档问答Agent（加载本地PDF，使用FAISS向量库，实现文档内容检索与智能</p>' metadata={'id': 168, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.4655}, {'x': 0.8991, 'y': 3.4655}, {'x': 0.8991, 'y': 3.4804}, {'x': 0.1834, 'y': 3.4804}]}
# page_content='<p id='169' data-category='paragraph' style='font-size:18px'>：开发一个"网页数据爬取Agent"（使用Selenium自动化打开网页，提取指定内容并整理成结</p>' metadata={'id': 169, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.7565}, {'x': 0.8967, 'y': 3.7565}, {'x': 0.8967, 'y': 3.7714}, {'x': 0.1834, 'y': 3.7714}]}
# page_content='<p id='170' data-category='paragraph' style='font-size:18px'>◦ 多Agent架构：主从模式（Master-Agent+Worker-Agent）、角色分工模式（规划Agent+执行</p>' metadata={'id': 170, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.8778}, {'x': 0.8495, 'y': 3.8778}, {'x': 0.8495, 'y': 3.8945}, {'x': 0.1168, 'y': 3.8945}]}
# page_content='<br><p id='171' data-category='paragraph' style='font-size:18px'>◦ LangChain Memory模块文档（LangChain Memory）</p>' metadata={'id': 171, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1139}, {'x': 0.5358, 'y': 3.1139}, {'x': 0.5358, 'y': 3.1307}, {'x': 0.1168, 'y': 3.1307}]}
# page_content='<p id='172' data-category='paragraph' style='font-size:18px'>◦ 工具定义规范：</p>' metadata={'id': 172, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.5867}, {'x': 0.2603, 'y': 3.5867}, {'x': 0.2603, 'y': 3.6035}, {'x': 0.1168, 'y': 3.6035}]}
# page_content='<br><p id='173' data-category='paragraph' style='font-size:18px'>◦ RAG架构：文档加载→文本分块→Embedding生成→向量存储→检索增强生成</p>' metadata={'id': 173, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.2957}, {'x': 0.7321, 'y': 3.2957}, {'x': 0.7321, 'y': 3.3125}, {'x': 0.1168, 'y': 3.3125}]}
# ...
# page_content='<p id='158' data-category='paragraph' style='font-size:16px'>• 动作指导 ：自然亲和，表情生动，参考美团2025年"踏青广告"演员风格</p>' metadata={'id': 158, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.7499}, {'x': 0.6603, 'y': 3.7499}, {'x': 0.6603, 'y': 3.765}, {'x': 0.0914, 'y': 3.765}]}
# page_content='<br><p id='159' data-category='paragraph' style='font-size:16px'>• 配音/音效</p>' metadata={'id': 159, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.5212}, {'x': 0.1932, 'y': 3.5212}, {'x': 0.1932, 'y': 3.5363}, {'x': 0.0914, 'y': 3.5363}]}
# page_content='<h1 id='160' style='font-size:20px'>二、视频制作指导</h1>' metadata={'id': 160, 'page': 3, 'category': 'heading1', 'coordinates': [{'x': 0.092, 'y': 4.8917}, {'x': 0.3012, 'y': 4.8917}, {'x': 0.3012, 'y': 4.9131}, {'x': 0.092, 'y': 4.9131}]}
# page_content='<br><p id='161' data-category='paragraph' style='font-size:16px'>：手机屏幕特写，手指点击"立即使用"按钮，镜头拉远显示不同人群同时使用美团红包的欢乐</p>' metadata={'id': 161, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.2451}, {'x': 0.9048, 'y': 3.2451}, {'x': 0.9048, 'y': 3.2601}, {'x': 0.1834, 'y': 3.2601}]}
# page_content='<p id='162' data-category='paragraph' style='font-size:16px'>：需标注"活动规则以APP显示为准"小字</p>' metadata={'id': 162, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.5964}, {'x': 0.4939, 'y': 3.5964}, {'x': 0.4939, 'y': 3.6114}, {'x': 0.1834, 'y': 3.6114}]}
# page_content='<p id='163' data-category='paragraph' style='font-size:16px'>：红包领取动作需统一为"双手比心"手势，增强品牌记忆点</p>' metadata={'id': 163, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.7751}, {'x': 0.6402, 'y': 3.7751}, {'x': 0.6402, 'y': 3.79}, {'x': 0.1834, 'y': 3.79}]}
# page_content='<br><p id='164' data-category='paragraph' style='font-size:16px'>：黑屏后渐显美团LOGO与活动信息，底部出现"美团外卖，送啥都快"辅助标语</p>' metadata={'id': 164, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.4712}, {'x': 0.7916, 'y': 3.4712}, {'x': 0.7916, 'y': 3.4861}, {'x': 0.1834, 'y': 3.4861}]}
# page_content='<br><p id='165' data-category='paragraph' style='font-size:16px'>：文字使用美团标准黑体，重点信息用红色加粗</p>' metadata={'id': 165, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.1657}, {'x': 0.5574, 'y': 3.1657}, {'x': 0.5574, 'y': 3.1807}, {'x': 0.1834, 'y': 3.1807}]}
# page_content='<p id='166' data-category='paragraph' style='font-size:16px'>：画面角落出现活动二维码</p>' metadata={'id': 166, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.3918}, {'x': 0.3986, 'y': 3.3918}, {'x': 0.3986, 'y': 3.4067}, {'x': 0.1834, 'y': 3.4067}]}
# page_content='<p id='167' data-category='paragraph' style='font-size:16px'>：美团黄与国庆红比例控制在3:1，避免色彩冲突</p>' metadata={'id': 167, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.8794}, {'x': 0.5618, 'y': 3.8794}, {'x': 0.5618, 'y': 3.8944}, {'x': 0.1834, 'y': 3.8944}]}
# page_content='<br><p id='168' data-category='paragraph' style='font-size:16px'>：沉稳旁白："10月1日至7日，每天可领3次，最高101元红包！"</p>' metadata={'id': 168, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1897, 'y': 3.1156}, {'x': 0.6849, 'y': 3.1156}, {'x': 0.6849, 'y': 3.1306}, {'x': 0.1897, 'y': 3.1306}]}
# page_content='<p id='169' data-category='paragraph' style='font-size:16px'>：美团slogan："美团一次，美一次！" + 音乐高潮</p>' metadata={'id': 169, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.1897, 'y': 3.3417}, {'x': 0.5719, 'y': 3.3417}, {'x': 0.5719, 'y': 3.3566}, {'x': 0.1897, 'y': 3.3566}]}
# page_content='<p id='170' data-category='paragraph' style='font-size:14px'>3/4</p>' metadata={'id': 170, 'page': 3, 'category': 'paragraph', 'coordinates': [{'x': 0.8825, 'y': 3.5161}, {'x': 0.907, 'y': 3.5161}, {'x': 0.907, 'y': 3.529}, {'x': 0.8825, 'y': 3.529}]}
# page_content='<p id='171' data-category='list'></p>' metadata={'id': 171, 'page': 4, 'category': 'list', 'coordinates': [{'x': 0.1141, 'y': 0.1027}, {'x': 0.6664, 'y': 0.1027}, {'x': 0.6664, 'y': 0.1711}, {'x': 0.1141, 'y': 0.1711}]}
# page_content='<p id='172' data-category='list'></p>' metadata={'id': 172, 'page': 4, 'category': 'list', 'coordinates': [{'x': 0.0974, 'y': 0.2316}, {'x': 0.7064, 'y': 0.2316}, {'x': 0.7064, 'y': 0.3015}, {'x': 0.0974, 'y': 0.3015}]}
# page_content='<p id='173' data-category='list'></p>' metadata={'id': 173, 'page': 4, 'category': 'list', 'coordinates': [{'x': 0.0986, 'y': 0.3609}, {'x': 0.7516, 'y': 0.3609}, {'x': 0.7516, 'y': 0.4287}, {'x': 0.0986, 'y': 0.4287}]}
# page_content='<p id='174' data-category='list'></p>' metadata={'id': 174, 'page': 4, 'category': 'list', 'coordinates': [{'x': 0.1159, 'y': 0.4365}, {'x': 0.5153, 'y': 0.4365}, {'x': 0.5153, 'y': 0.5045}, {'x': 0.1159, 'y': 0.5045}]}
# page_content='<p id='175' data-category='list'></p>' metadata={'id': 175, 'page': 4, 'category': 'list', 'coordinates': [{'x': 0.0963, 'y': 0.5647}, {'x': 0.4652, 'y': 0.5647}, {'x': 0.4652, 'y': 0.6351}, {'x': 0.0963, 'y': 0.6351}]}
# page_content='<p id='176' data-category='list'></p>' metadata={'id': 176, 'page': 4, 'category': 'list', 'coordinates': [{'x': 0.0928, 'y': 0.6993}, {'x': 0.8895, 'y': 0.6993}, {'x': 0.8895, 'y': 0.7695}, {'x': 0.0928, 'y': 0.7695}]}
# page_content='<p id='177' data-category='paragraph' style='font-size:16px'>1. 节奏参考</p>' metadata={'id': 177, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0964, 'y': 3.713}, {'x': 0.187, 'y': 3.713}, {'x': 0.187, 'y': 3.7282}, {'x': 0.0964, 'y': 3.7282}]}
# page_content='<br><p id='178' data-category='paragraph' style='font-size:18px'>4.</p>' metadata={'id': 178, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0928, 'y': 3.4144}, {'x': 0.1134, 'y': 3.4144}, {'x': 0.1134, 'y': 3.431}, {'x': 0.0928, 'y': 3.431}]}
# page_content='<br><p id='179' data-category='paragraph' style='font-size:18px'>3.</p>' metadata={'id': 179, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0928, 'y': 3.2849}, {'x': 0.1134, 'y': 3.2849}, {'x': 0.1134, 'y': 3.3016}, {'x': 0.0928, 'y': 3.3016}]}
# page_content='<p id='180' data-category='paragraph' style='font-size:16px'>• 字体规范 ：红包动画使用"粒子飘散"效果，参考美团2025年小象超市年货节KV设计</p>' metadata={'id': 180, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.3991}, {'x': 0.7515, 'y': 3.3991}, {'x': 0.7515, 'y': 3.4142}, {'x': 0.0914, 'y': 3.4142}]}
# page_content='<p id='181' data-category='paragraph' style='font-size:16px'>2. 色彩标准</p>' metadata={'id': 181, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0959, 'y': 3.7381}, {'x': 0.187, 'y': 3.7381}, {'x': 0.187, 'y': 3.7532}, {'x': 0.0959, 'y': 3.7532}]}
# page_content='<br><p id='182' data-category='paragraph' style='font-size:16px'>• 光线处理 ：以"环绕推进"为主，避免过度抖动</p>' metadata={'id': 182, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.2697}, {'x': 0.4638, 'y': 3.2697}, {'x': 0.4638, 'y': 3.2848}, {'x': 0.0914, 'y': 3.2848}]}
# page_content='<p id='183' data-category='paragraph' style='font-size:16px'>• 特效风格 ：前30秒每秒1-2个镜头，后30秒加快至每秒2-3个镜头</p>' metadata={'id': 183, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.374}, {'x': 0.6155, 'y': 3.374}, {'x': 0.6155, 'y': 3.3892}, {'x': 0.0914, 'y': 3.3892}]}
# page_content='<br><p id='184' data-category='paragraph' style='font-size:16px'>• 运镜方式 60fps，确保慢动作场景清晰</p>' metadata={'id': 184, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.2446}, {'x': 0.4109, 'y': 3.2446}, {'x': 0.4109, 'y': 3.2598}, {'x': 0.0914, 'y': 3.2598}]}
# page_content='<p id='185' data-category='paragraph' style='font-size:16px'>• 需展示活动时间：2025年10月1日-10月7日</p>' metadata={'id': 185, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.6282}, {'x': 0.4479, 'y': 3.6282}, {'x': 0.4479, 'y': 3.6432}, {'x': 0.0914, 'y': 3.6432}]}
# page_content='<br><p id='186' data-category='paragraph' style='font-size:16px'>• 禁用"最大""最高"等绝对化用语（改用"至高"）</p>' metadata={'id': 186, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.6032}, {'x': 0.4706, 'y': 3.6032}, {'x': 0.4706, 'y': 3.6182}, {'x': 0.0914, 'y': 3.6182}]}
# page_content='<h1 id='187' style='font-size:20px'>三、参考案例与视觉素材</h1>' metadata={'id': 187, 'page': 4, 'category': 'heading1', 'coordinates': [{'x': 0.092, 'y': 4.9235}, {'x': 0.3779, 'y': 4.9235}, {'x': 0.3779, 'y': 4.9449}, {'x': 0.092, 'y': 4.9449}]}
# page_content='<br><p id='188' data-category='paragraph' style='font-size:16px'>3.</p>' metadata={'id': 188, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0964, 'y': 3.7635}, {'x': 0.1121, 'y': 3.7635}, {'x': 0.1121, 'y': 3.7778}, {'x': 0.0964, 'y': 3.7778}]}
# page_content='<br><p id='189' data-category='paragraph' style='font-size:16px'>• 所有优惠信息需标注"具体以APP显示为准"</p>' metadata={'id': 189, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.5783}, {'x': 0.441, 'y': 3.5783}, {'x': 0.441, 'y': 3.5933}, {'x': 0.0914, 'y': 3.5933}]}
# page_content='<p id='190' data-category='paragraph' style='font-size:18px'>5.</p>' metadata={'id': 190, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0928, 'y': 3.6186}, {'x': 0.1134, 'y': 3.6186}, {'x': 0.1134, 'y': 3.6353}, {'x': 0.0928, 'y': 3.6353}]}
# page_content='<br><p id='191' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 191, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.0905}, {'x': 0.1125, 'y': 3.0905}, {'x': 0.1125, 'y': 3.1055}, {'x': 0.0914, 'y': 3.1055}]}
# page_content='<p id='192' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 192, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.4242}, {'x': 0.1125, 'y': 3.4242}, {'x': 0.1125, 'y': 3.4391}, {'x': 0.0914, 'y': 3.4391}]}
# page_content='<br><p id='193' data-category='paragraph' style='font-size:16px'>•</p>' metadata={'id': 193, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.0914, 'y': 3.2947}, {'x': 0.1125, 'y': 3.2947}, {'x': 0.1125, 'y': 3.3097}, {'x': 0.0914, 'y': 3.3097}]}
# page_content='<p id='194' data-category='paragraph' style='font-size:16px'>：美团2025年"小象超市年货节"KV设计（古今融合风格）</p>' metadata={'id': 194, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.2187, 'y': 3.7132}, {'x': 0.6633, 'y': 3.7132}, {'x': 0.6633, 'y': 3.7281}, {'x': 0.2187, 'y': 3.7281}]}
# page_content='<br><p id='195' data-category='paragraph' style='font-size:16px'>：室外场景优先自然光，室内需保证美团黄准确还原（色温5500K）</p>' metadata={'id': 195, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.2948}, {'x': 0.7111, 'y': 3.2948}, {'x': 0.7111, 'y': 3.3098}, {'x': 0.1834, 'y': 3.3098}]}
# page_content='<p id='196' data-category='paragraph' style='font-size:16px'>：美团2025年"18神券节"魔性广告（快节奏切换）</p>' metadata={'id': 196, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.7382}, {'x': 0.5729, 'y': 3.7382}, {'x': 0.5729, 'y': 3.7532}, {'x': 0.1834, 'y': 3.7532}]}
# page_content='<br><p id='197' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 197, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.4243}, {'x': 0.2046, 'y': 3.4243}, {'x': 0.2046, 'y': 3.4392}, {'x': 0.1834, 'y': 3.4392}]}
# page_content='<br><p id='198' data-category='paragraph' style='font-size:16px'>：4K</p>' metadata={'id': 198, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1482, 'y': 3.2447}, {'x': 0.1889, 'y': 3.2447}, {'x': 0.1889, 'y': 3.2597}, {'x': 0.1482, 'y': 3.2597}]}
# page_content='<br><p id='199' data-category='paragraph' style='font-size:16px'>：</p>' metadata={'id': 199, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.0906}, {'x': 0.2046, 'y': 3.0906}, {'x': 0.2046, 'y': 3.1056}, {'x': 0.1834, 'y': 3.1056}]}
# page_content='<p id='200' data-category='paragraph' style='font-size:16px'>◦ 优惠信息：红色加粗+黄色描边</p>' metadata={'id': 200, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.4974}, {'x': 0.3752, 'y': 3.4974}, {'x': 0.3752, 'y': 3.5142}, {'x': 0.1168, 'y': 3.5142}]}
# page_content='<p id='201' data-category='paragraph' style='font-size:18px'>合规审查要点</p>' metadata={'id': 201, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.116, 'y': 3.941}, {'x': 0.2429, 'y': 3.941}, {'x': 0.2429, 'y': 3.9581}, {'x': 0.116, 'y': 3.9581}]}
# page_content='<br><p id='202' data-category='paragraph' style='font-size:16px'>◦ 标题：思源黑体Bold（中文）+ Arial Bold（英文）</p>' metadata={'id': 202, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.4475}, {'x': 0.5188, 'y': 3.4475}, {'x': 0.5188, 'y': 3.4643}, {'x': 0.1168, 'y': 3.4643}]}
# page_content='<br><p id='203' data-category='paragraph' style='font-size:16px'>◦ 红包道具：实体红包需印有袋鼠剪影+国庆祥云图案</p>' metadata={'id': 203, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1388}, {'x': 0.534, 'y': 3.1388}, {'x': 0.534, 'y': 3.1556}, {'x': 0.1168, 'y': 3.1556}]}
# page_content='<br><p id='204' data-category='paragraph' style='font-size:16px'>◦ 背景板：景区场景需出现"3小时出游圈"标识（参考尼尔森消费趋势）</p>' metadata={'id': 204, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1638}, {'x': 0.67, 'y': 3.1638}, {'x': 0.67, 'y': 3.1805}, {'x': 0.1168, 'y': 3.1805}]}
# page_content='<br><p id='205' data-category='paragraph' style='font-size:16px'>道具清单</p>' metadata={'id': 205, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.0656}, {'x': 0.187, 'y': 3.0656}, {'x': 0.187, 'y': 3.0805}, {'x': 0.1129, 'y': 3.0805}]}
# page_content='<p id='206' data-category='paragraph' style='font-size:16px'>剪辑节奏</p>' metadata={'id': 206, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.3491}, {'x': 0.187, 'y': 3.3491}, {'x': 0.187, 'y': 3.3641}, {'x': 0.1129, 'y': 3.3641}]}
# page_content='<p id='207' data-category='paragraph' style='font-size:16px'>品牌视觉参考</p>' metadata={'id': 207, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.6881}, {'x': 0.2222, 'y': 3.6881}, {'x': 0.2222, 'y': 3.7031}, {'x': 0.1129, 'y': 3.7031}]}
# page_content='<br><p id='208' data-category='paragraph' style='font-size:16px'>◦ 手机：统一使用iPhone 15 Pro（黑色），预装美团APP最新版本</p>' metadata={'id': 208, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.1139}, {'x': 0.6234, 'y': 3.1139}, {'x': 0.6234, 'y': 3.1307}, {'x': 0.1168, 'y': 3.1307}]}
# page_content='<p id='209' data-category='paragraph' style='font-size:16px'>帧率</p>' metadata={'id': 209, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1129, 'y': 3.2197}, {'x': 0.1517, 'y': 3.2197}, {'x': 0.1517, 'y': 3.2347}, {'x': 0.1129, 'y': 3.2347}]}
# page_content='<p id='210' data-category='paragraph' style='font-size:16px'>：美团黄（Pantone 109C，CMYK: 0,15,100,0）；国庆红（Pantone 186C，CMYK: 0,90,80,5）</p>' metadata={'id': 210, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1834, 'y': 3.7633}, {'x': 0.8918, 'y': 3.7633}, {'x': 0.8918, 'y': 3.7782}, {'x': 0.1834, 'y': 3.7782}]}
# page_content='<br><p id='211' data-category='paragraph' style='font-size:16px'>◦ 正文：思源黑体Regular，字号不小于24pt</p>' metadata={'id': 211, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.1168, 'y': 3.4725}, {'x': 0.4587, 'y': 3.4725}, {'x': 0.4587, 'y': 3.4893}, {'x': 0.1168, 'y': 3.4893}]}
# page_content='<p id='212' data-category='paragraph' style='font-size:18px'>拍摄技术要求</p>' metadata={'id': 212, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.116, 'y': 3.6074}, {'x': 0.2429, 'y': 3.6074}, {'x': 0.2429, 'y': 3.6245}, {'x': 0.116, 'y': 3.6245}]}
# page_content='<p id='213' data-category='paragraph' style='font-size:18px'>后期制作标准</p>' metadata={'id': 213, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.116, 'y': 3.7368}, {'x': 0.2429, 'y': 3.7368}, {'x': 0.2429, 'y': 3.7539}, {'x': 0.116, 'y': 3.7539}]}
# page_content='<br><p id='214' data-category='paragraph' style='font-size:14px'>4/4</p>' metadata={'id': 214, 'page': 4, 'category': 'paragraph', 'coordinates': [{'x': 0.8825, 'y': 3.5161}, {'x': 0.907, 'y': 3.5161}, {'x': 0.907, 'y': 3.529}, {'x': 0.8825, 'y': 3.529}]}

# %%
vectorstore = DocArrayInMemorySearch.from_documents(
    docs, embedding=UpstageEmbeddings(model="solar-embedding-1-large")
)
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 5})

template = """Answer the question based only on the following context:
{context}

Question: {question}
"""
prompt = ChatPromptTemplate.from_template(template)
output_parser = StrOutputParser()

retrieved_docs = retriever.invoke("一般几天后可以编写完整的agent？")

groundedness_check = UpstageGroundednessCheck()
groundedness = ""
while groundedness != "grounded":
    chain: RunnableSerializable = RunnablePassthrough() | prompt | model | output_parser

    result = chain.invoke(
        {
            "context": retrieved_docs,
            "question": "一般几天后可以编写完整的agent？",
        }
    )

    groundedness = groundedness_check.invoke(
        {
            "context": retrieved_docs,
            "answer": result,
        }
    )

# %%
print(result)
# Out:
# 根据所提供的上下文，项目实战阶段持续3天，在这个阶段预计可以编写完整的Agent。

# %%
print(groundedness)
# Out:
# grounded
